# %%
import pandas as pd
df = pd.read_csv("sample1.csv")
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.year
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 20119    2023
# 20120    2023
# 20121    2023
# 20122    2023
# 20123    2023
# Name: year, Length: 20124, dtype: int64

# %%
df_2011 =df[df.year==2011]
df_2012 =df[df.year==2012]
df_2011
# Out:
#       year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0     2011                    A  Agriculture, Forestry and Fishing
# 1     2011                    A  Agriculture, Forestry and Fishing
# 2     2011                    A  Agriculture, Forestry and Fishing
# 3     2011                    A  Agriculture, Forestry and Fishing
# 4     2011                    A  Agriculture, Forestry and Fishing
# ...    ...                  ...                                ...
# 1543  2011                  all                     All Industries
# 1544  2011                  all                     All Industries
# 1545  2011                  all                     All Industries
# 1546  2011                  all                     All Industries
# 1547  2011                  all                     All Industries
#
#        rme_size_grp                                         variable    value  \
# 0               a_0                                    Activity unit    46134
# ...

# %%
df_2012
# Out:
#       year industry_code_ANZSIC               industry_name_ANZSIC  \
# 1548  2012                    A  Agriculture, Forestry and Fishing
# 1549  2012                    A  Agriculture, Forestry and Fishing
# 1550  2012                    A  Agriculture, Forestry and Fishing
# 1551  2012                    A  Agriculture, Forestry and Fishing
# 1552  2012                    A  Agriculture, Forestry and Fishing
# ...    ...                  ...                                ...
# 3091  2012                  all                     All Industries
# 3092  2012                  all                     All Industries
# 3093  2012                  all                     All Industries
# 3094  2012                  all                     All Industries
# 3095  2012                  all                     All Industries
#
#        rme_size_grp                                         variable    value  \
# 1548            a_0                                    Activity unit    45264
# ...

# %%
dir(df.value) #see all the function related to specific column
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df_2012.value.max()
# Out:
# 'C'

# %%
df.columns
# Out:
# Index(['year', 'industry_code_ANZSIC', 'industry_name_ANZSIC', 'rme_size_grp',
#        'variable', 'value', 'unit'],
#       dtype='object')

# %%
df['industry_name_ANZSIC'].unique()
# Out:
# array(['Agriculture, Forestry and Fishing', 'Mining', 'Manufacturing',
#        'Electricity, Gas, Water and Waste Services', 'Construction',
#        'Wholesale Trade', 'Retail Trade',
#        'Accommodation and Food Services',
#        'Transport, Postal and Warehousing',
#        'Information Media and Telecommunications',
#        'Financial and Insurance Services',
#        'Rental, Hiring and Real Estate Services',
#        'Professional, Scientific and Technical Services',
#        'Administrative and Support Services',
#        'Public Administration and Safety', 'Education and Training',
#        'Health Care and Social Assistance',
#        'Arts and Recreation Services', 'Other Services', 'All Industries'],
#       dtype=object)

# %%
df.industry_name_ANZSIC.value_counts()
# Out:
# industry_name_ANZSIC
# Agriculture, Forestry and Fishing                  1053
# Mining                                             1053
# Other Services                                     1053
# Arts and Recreation Services                       1053
# Health Care and Social Assistance                  1053
# Education and Training                             1053
# Public Administration and Safety                   1053
# Administrative and Support Services                1053
# Professional, Scientific and Technical Services    1053
# Rental, Hiring and Real Estate Services            1053
# Financial and Insurance Services                   1053
# Information Media and Telecommunications           1053
# Transport, Postal and Warehousing                  1053
# Accommodation and Food Services                    1053
# Retail Trade                                       1053
# Wholesale Trade                                    1053
# ...

# %%
df.year.min() # minimum year
# Out:
# 2011

# %%
 df.year.max() # maximum year
# Out:
# 2023

# %%
df[(df.year == df.year.max()) | (df.year == df.year.min())]  # this will give the minimum year and maximum year all rows
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df["age"] = df['year'].apply(lambda x: 2024 - x) # lambda function is a for loop and get a value of that variable and looping
df.head(5)
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit  \
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)
#
#    age
# 0   13
# 1   13
# 2   13
# ...

# %%
#df['profit'] = df.apply(lambda x: x['value'] - x['capital'], axis=1)
df['profit'] = df.apply(lambda x: x['value'] * 5, axis=1)
df.head(4)
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit  \
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
#
#    age                     profit
# 0   13  4613446134461344613446134
# 1   13                      00000
# 2   13            279279279279279
# 3   13       81878187818781878187

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20124, step=1)

# %%
df.set_index("", inplace = True) # set index as a specific column, then we can call specific column row name , as a key, 
#then it will give the valyes like other row values
#df.loc("index name")  /// can give multiple rows also "", ""
#df.iloc[2:5]
#df.reset_index(inplace = True)   this will reset the index as befor
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2488\1790918816.py in ?()
# ----> 1 df.set_index("", inplace = True) # set index as a specific column, then we can call specific column row name , as a key,
#       2 #then it will give the valyes like other row values
#       3 #df.loc("index name")  /// can give multiple rows also "", ""
#       4 #df.iloc[2:5]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
# ...

# %%
 df['new_year'] = df["year"]+df["year"]

# %%
df

# %%
df.to_csv("newyear.csv", index=False)

# %%
ex = pd.read_excel('file_example_XLS_50.xlsx')

# Replacing null values in the 'movie_budget' column with 0
#ex['movie_budget'].fillna(0, inplace=True)
ex

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

# Creating a DataFrame from the dictionary
dictonory_to_df= pd.DataFrame(data)
dictonory_to_df
data2 = {
    'Product': ['Laptop', 'Tablet', 'Smartphone', 'Headphones'],
    'Price': [1200, 300, 800, 150],
    'Stock': [30, 50, 100, 75]
}

# Creating a DataFrame from the second dictionary
dictonory_to_df2 = pd.DataFrame(data2)
dictonory_to_df2
# Out:
#       Product  Price  Stock
# 0      Laptop   1200     30
# 1      Tablet    300     50
# 2  Smartphone    800    100
# 3  Headphones    150     75

# %%
with pd.ExcelWriter('output_data.xlsx') as writer:
    dictonory_to_df.to_excel(writer, sheet_name='People', index=False)
    dictonory_to_df2.to_excel(writer, sheet_name='Products', index=False)

# %%
with pd.ExcelWriter('output2.xlsx') as writer:
    dictonory_to_df.to_excel(writer, sheet_name='People', index=False)
    dictonory_to_df2.to_excel(writer, sheet_name='Products', index=False)

# %%
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.replace('All Industries', 'ALL')
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                                ALL
# 20120  2023                  all                                ALL
# 20121  2023                  all                                ALL
# 20122  2023                  all                                ALL
# 20123  2023                  all                                ALL
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.replace(
    {
        'industry_name_ANZSIC' : 'ALL',
    'year':2011
        
    }, 'Nothing'
)
# Out:
#           year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      Nothing                    A  Agriculture, Forestry and Fishing
# 1      Nothing                    A  Agriculture, Forestry and Fishing
# 2      Nothing                    A  Agriculture, Forestry and Fishing
# 3      Nothing                    A  Agriculture, Forestry and Fishing
# 4      Nothing                    A  Agriculture, Forestry and Fishing
# ...        ...                  ...                                ...
# 20119     2023                  all                     All Industries
# 20120     2023                  all                     All Industries
# 20121     2023                  all                     All Industries
# 20122     2023                  all                     All Industries
# 20123     2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# ...

# %%
df.replace(
    {
    'Nothing' : 'ALL',
    2023:2024
    }
)
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2024                  all                     All Industries
# 20120  2024                  all                     All Industries
# 20121  2024                  all                     All Industries
# 20122  2024                  all                     All Industries
# 20123  2024                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df = pd.DataFrame({
    'score':['exceptional','average','good','poor','average','exceptional'],
    'student': ['rob','maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'good'],[1,2])
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2            2  parthiv
# 3            1      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'good', 'exceptional'],[1,2, 3])
# Out:
#      score  student
# 0        3      rob
# 1  average     maya
# 2        2  parthiv
# 3        1      tom
# 4  average   julian
# 5        3    erica
